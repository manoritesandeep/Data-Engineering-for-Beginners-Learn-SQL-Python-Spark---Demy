# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10
b = 20
res = a + b
print(f"Sum of {a} and {b} is {res}")
# Out:
# Sum of 10 and 20 is 30

# %%
def sumN(n):
    return (n*(n+1))/2

# %%
sumN(10)
# Out:
# 55.0

# %%
def sumN(n):
    return (n*(n+1))//2

# %%
sumN(10)
# Out:
# 55

# %%
l = [1, "Hello", None, 2, 4]

result = 0

for i in l:
    if type(i) == int:
        result += i

result
# Out:
# 7
