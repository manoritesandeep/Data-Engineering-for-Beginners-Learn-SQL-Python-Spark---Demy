# %%
string = "test"

# %%
print(" ".join(string))

rev_string = ""
for i in " ".join(string):
    print(i)
    rev_string = i + rev_string
print(rev_string)
# Out:
# t e s t
# t
#
# e
#
# s
#
# t
# t s e t

# %%
rev_string = string[::-1]
print(rev_string)
# Out:
# tset
